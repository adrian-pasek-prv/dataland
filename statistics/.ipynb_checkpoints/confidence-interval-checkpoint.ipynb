# %% [markdown]
# ### 1. Getting the data

# %%
import pandas as pd
import numpy as np
import requests

# %%
# Get the data from justjoin.it API
response = requests.get('https://justjoin.it/api/offers')
json = response.json()

# %%
# Load json to df using .json_normalize
json_normalize = pd.json_normalize(json)
json_normalize.head(2)
# Out:
#                                       title            street      city  \
# 0  Automation Tester - Car Sharing Platform          Złota 59  Warszawa
# 1              Remote Mid Android Developer  Skierniewicka 10  Warszawa
#
#   country_code                address_text marker_icon workplace_type  \
# 0           PL          Złota 59, Warszawa     testing  partly_remote
# 1           PL  Skierniewicka 10, Warszawa      mobile         remote
#
#   company_name         company_url company_size  ... remote_interview  \
# 0         ITDS  http://www.itds.pl         200+  ...             True
# 1       Mobica   http://mobica.com         100+  ...             True
#
#   open_to_hire_ukrainians                                           id  \
# 0                    True  itds-automation-tester-car-sharing-platform
# 1                   False          mobica-remote-mid-android-developer
#
#   display_offer                                   employment_types  \
# 0          True  [{'type': 'b2b', 'salary': {'from': 10000, 'to...
# 1          True  [{'type': 'b2b', 'salary': {'from': 11760, 'to...
#
#                                     company_logo_url  \
# 0  https://bucket.justjoin.it/offers/company_logo...
# 1  https://bucket.justjoin.it/offers/company_logo...
#
#                                               skills  remote  \
# 0  [{'name': 'Python', 'level': 3}, {'name': 'Jav...   False
# 1  [{'name': 'RxJava', 'level': 3}, {'name': 'Kot...    True
#
#                                        multilocation way_of_apply
# 0  [{'city': 'Warszawa', 'street': 'Złota 59', 's...         form
# 1  [{'city': 'Warszawa', 'slug': 'mobica-remote-m...         form
#
# [2 rows x 24 columns]

# %% [markdown]
# We have some records that contain nested records. We can use json_normalize once again, this time with parameters
# - record_path - allows to indicate a nested field
# - meta - concatenates additional columns that are not nested

# %%
df = pd.json_normalize(json, record_path='employment_types', meta=['id', 'title', 'marker_icon', 'workplace_type',
                                                                   'remote', 'published_at'])
df.head()
# Out:
#         type  salary.from  salary.to salary.currency  salary  \
# 0        b2b      10000.0    15000.0             pln     NaN
# 1  permanent       8000.0    11500.0             pln     NaN
# 2        b2b      11760.0    22680.0             pln     NaN
# 3        b2b       6000.0    10000.0             pln     NaN
# 4  permanent      16000.0    22000.0             pln     NaN
#
#                                             id  \
# 0  itds-automation-tester-car-sharing-platform
# 1  itds-automation-tester-car-sharing-platform
# 2          mobica-remote-mid-android-developer
# 3                     codibly-it-administrator
# 4                globallogic-autosar-architect
#
#                                       title   marker_icon workplace_type  \
# 0  Automation Tester - Car Sharing Platform       testing  partly_remote
# 1  Automation Tester - Car Sharing Platform       testing  partly_remote
# 2              Remote Mid Android Developer        mobile         remote
# 3                          IT Administrator         admin         office
# 4                         AUTOSAR Architect  architecture         remote
#
#   remote              published_at
# 0  False  2022-06-18T08:00:26.475Z
# 1  False  2022-06-18T08:00:26.475Z
# 2   True  2022-06-18T08:00:26.475Z
# 3  False  2022-06-18T08:00:26.475Z
# 4   True  2022-06-18T08:00:26.475Z

# %%
# Reorder columns and get rid of "salary" column
df = df.reindex(columns=['id', 'title', 'marker_icon', 'workplace_type', 'remote', 'published_at',
                        'type', 'salary.from', 'salary.to', 'salary.currency'])
# Check data types
df.dtypes
# Out:
# id                  object
# title               object
# marker_icon         object
# workplace_type      object
# remote              object
# published_at        object
# type                object
# salary.from        float64
# salary.to          float64
# salary.currency     object
# dtype: object

# %%
# Convert columns to specified formats
df['remote'] = df['remote'].astype('bool')
df['published_at'] = pd.to_datetime(df['published_at'], utc=False)

# %%
df.head()
# Out:
#                                             id  \
# 0  itds-automation-tester-car-sharing-platform
# 1  itds-automation-tester-car-sharing-platform
# 2          mobica-remote-mid-android-developer
# 3                     codibly-it-administrator
# 4                globallogic-autosar-architect
#
#                                       title   marker_icon workplace_type  \
# 0  Automation Tester - Car Sharing Platform       testing  partly_remote
# 1  Automation Tester - Car Sharing Platform       testing  partly_remote
# 2              Remote Mid Android Developer        mobile         remote
# 3                          IT Administrator         admin         office
# 4                         AUTOSAR Architect  architecture         remote
#
#    remote published_at       type  salary.from  salary.to salary.currency
# 0   False   2022-06-18        b2b      10000.0    15000.0             pln
# 1   False   2022-06-18  permanent       8000.0    11500.0             pln
# 2    True   2022-06-18        b2b      11760.0    22680.0             pln
# 3   False   2022-06-18        b2b       6000.0    10000.0             pln
# 4    True   2022-06-18  permanent      16000.0    22000.0             pln
